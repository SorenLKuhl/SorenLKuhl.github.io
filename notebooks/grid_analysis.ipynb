# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import folium
from folium import DivIcon, Marker, Map

# %%
df_reviews = pd.read_csv("../data/philadelphia_restaurant_reviews.csv")
df_business = pd.read_json("../data/yelp_academic_dataset_business.json", lines=True)
restaurant_ids = set()
for _, b in df_business.iterrows():
    if b['categories'] and 'Burger' in b['categories'] and 'Restaurants' in b['categories']:
        restaurant_ids.add(b['business_id'])
df_reviews = df_reviews[df_reviews['business_id'].isin(restaurant_ids)]
df = df_reviews.merge(df_business, on='business_id', how='left')
df = df.dropna(subset=['latitude', 'longitude'])
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  cvQXRFLCyr0S7EgFb4lZqw  ZGjgfSvjQK886kiTzLwfLQ  EtKSTHV5Qx_Q7Aur9o4kQQ
# 1  3dVcGYz6GokuEytLrfG8bA  FEI0XkOrUHufSW_rfOTPAA  Dv6RfXLYe1atjgz3Xf4GGw
# 2  -xM8cH4AeVzgTJBQHlxfUQ  ZaMB7VbOwaARjxdhXjODxA  EtKSTHV5Qx_Q7Aur9o4kQQ
# 3  UqZyX64mgw1vJ1ffnxODjA  cARxOd_5yKCgsCbUZ5ED4Q  EtKSTHV5Qx_Q7Aur9o4kQQ
# 4  nCdhMSQA0apDuB_oho5ang  2dyfZNhtyuHdestczTgWjQ  Dv6RfXLYe1atjgz3Xf4GGw
#
#    stars_x  useful  funny  cool  \
# 0        5       3      1     1
# 1        4       1      0     0
# 2        5       0      0     0
# 3        4       0      0     0
# 4        4       0      0     2
#
#                                                 text                 date  \
# 0  On a scale of one to things that are awesome, ...  2009-10-14 01:15:04
# 1  Good food, reasonably priced, and nice staff. ...  2012-12-04 23:58:36
# 2  Picked up takeout from Village Whiskey (so I c...  2014-11-30 01:55:57
# 3  There is a great selection of whiskey/bourbon ...  2014-10-11 12:54:43
# 4  Super lunch option\nWatch out for the yoga mat...  2012-08-15 19:17:49
#
#               name  ... state postal_code   latitude  longitude  stars_y  \
# 0  Village Whiskey  ...    PA       19103  39.951417 -75.173768      4.0
# 1       HipCityVeg  ...    PA       19103  39.950774 -75.170397      4.0
# 2  Village Whiskey  ...    PA       19103  39.951417 -75.173768      4.0
# 3  Village Whiskey  ...    PA       19103  39.951417 -75.173768      4.0
# 4       HipCityVeg  ...    PA       19103  39.950774 -75.170397      4.0
#
#    review_count  is_open                                         attributes  \
# 0          1553        1  {'RestaurantsReservations': 'False', 'Restaura...
# 1          1082        1  {'RestaurantsAttire': 'u'casual'', 'NoiseLevel...
# 2          1553        1  {'RestaurantsReservations': 'False', 'Restaura...
# 3          1553        1  {'RestaurantsReservations': 'False', 'Restaura...
# 4          1082        1  {'RestaurantsAttire': 'u'casual'', 'NoiseLevel...
#
#                                           categories  \
# 0  Bars, Nightlife, Whiskey Bars, Burgers, Restau...
# 1            Burgers, Vegetarian, Restaurants, Vegan
# 2  Bars, Nightlife, Whiskey Bars, Burgers, Restau...
# 3  Bars, Nightlife, Whiskey Bars, Burgers, Restau...
# 4            Burgers, Vegetarian, Restaurants, Vegan
#
#                                                hours
# 0  {'Wednesday': '16:0-21:0', 'Thursday': '16:0-2...
# 1  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 2  {'Wednesday': '16:0-21:0', 'Thursday': '16:0-2...
# 3  {'Wednesday': '16:0-21:0', 'Thursday': '16:0-2...
# 4  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
#
# [5 rows x 22 columns]

# %%
# TODO:
# 1. Add dots of restaurants to the map
# 2. tweak opacity?
# 3. Add a legend for the colors
# 4. Maybe filter to show grids for x number of review or restaurants?
# 5. Tweak categories to show interesting ones (e.g. burger, pizza, etc.) and NOT 'restaurants' or 'Food'
# 6. Increase grid size?

# Split the datasets into grid cells
df['grid_x'] = (df['longitude'] - df['longitude'].min()) // 0.01
df['grid_y'] = (df['latitude'] - df['latitude'].min()) // 0.01
df['grid'] = df['grid_x'].astype(int).astype(str) + '_' + df['grid_y'].astype(int).astype(str)

restaurant_types = df['categories'].str.split(',').apply(lambda x: [i.strip() for i in x])

# Count the number of reviews in each grid cell
df_counts = df.groupby('grid').size().reset_index(name='count')
# Remove grid cells with less than 50 reviews
# df_counts = df_counts[df_counts['count'] >= 50]
# Add average rating to the grid cells
df_avg_rating = df.groupby('grid')['stars_x'].mean().reset_index(name='avg_rating')
df_counts = df_counts.merge(df_avg_rating, on='grid', how='left')
# Add the 'categories' column to the grid cells
df_categories = df[['grid', 'categories']].drop_duplicates(subset='grid')
df_counts = df_counts.merge(df_categories, on='grid', how='left')
# Create a grid map of the city
grid_map = folium.Map(
                      max_bounds=True, 
                      location=[df['latitude'].mean(), 
                                df['longitude'].mean()], 
                      zoom_start=12,
                      min_zoom=11,
                      min_lat=df['latitude'].min() - 0.1,
                      max_lat=df['latitude'].max() + 0.1,
                      min_lon=df['longitude'].min() - 0.1,
                      max_lon=df['longitude'].max() + 0.1,
)
# Add the grid cells to the map
cmap = plt.get_cmap('RdYlGn')  # This returns a colormap that can be mapped from 0 to 1

show = True
# iterate over the top 10 restaurant types
for restaurant_type in restaurant_types.explode().value_counts().head(10).index:
    fg = folium.FeatureGroup(name=restaurant_type, show=show)
    show = False  # Only show the first feature group
    subset = df_counts[df_counts['categories'].str.contains(restaurant_type)]
    
    
    for _, row in subset.iterrows():
        grid_x, grid_y = map(int, row['grid'].split('_'))
        lat = df['latitude'].min() + (grid_y + 0.5) * 0.01
        lon = df['longitude'].min() + (grid_x + 0.5) * 0.01
        
        # Normalize rating to [0,1] and convert to hex
        normalized_rating = row['avg_rating'] / 5
        rgba = cmap(normalized_rating)
        hex_color = matplotlib.colors.rgb2hex(rgba)
        
        folium.Rectangle(
            bounds=[[lat - 0.005, lon - 0.005], [lat + 0.005, lon + 0.005]],
            color=None,
            fill=True,
            fill_color=hex_color,
            fill_opacity=0.7,
            popup=f'Count: {row["count"]}<br>Avg Rating: {row["avg_rating"]}',
        ).add_to(fg)
        
        # Add a marker for the restaurants in the grid cell
        restaurants_in_cell = df[(df['grid'] == row['grid']) & (df['categories'].str.contains(restaurant_type))]
        for _, restaurant in restaurants_in_cell.iterrows():
            folium.Marker(
                location=[restaurant['latitude'], restaurant['longitude']],
                icon=DivIcon(
                    html=f'<div style="font-size: 10pt; color: black;">{restaurant["name"]}</div>',
                    class_name='marker',
                ),
                popup=f'{restaurant["name"]}<br>Rating: {restaurant["stars_x"]}',
            ).add_to(fg)
        
    fg.add_to(grid_map)
    
# Add layer control
folium.LayerControl(collapsed=False).add_to(grid_map)

grid_map
# Out:
# C:\Users\soren\AppData\Local\Temp\ipykernel_5876\2420164599.py:46: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   subset = df_counts[df_counts['categories'].str.contains(restaurant_type)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 85
#      82 # Add layer control
#      83 folium.LayerControl(collapsed=False).add_to(grid_map)
# ---> 85 grid_map
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\folium.py:335, in Map._repr_html_(self, **kwargs)
#     333     self._parent = None
#     334 else:
# --> 335     out = self._parent._repr_html_(**kwargs)
#     336 return out
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:410, in Figure._repr_html_(self, **kwargs)
#     408 def _repr_html_(self, **kwargs) -> str:
#     409     """Displays the Figure in a Jupyter notebook."""
# --> 410     html = escape(self.render(**kwargs))
#     411     if self.height is None:
#     412         iframe = (
#     413             '<div style="width:{width};">'
#     414             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     420             "</div></div>"
#     421         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:405, in Figure.render(self, **kwargs)
#     403 """Renders the HTML representation of the element."""
#     404 for name, child in self._children.items():
# --> 405     child.render(**kwargs)
#     406 return self._template.render(this=self, kwargs=kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\folium.py:417, in Map.render(self, **kwargs)
#     390 figure.header.add_child(
#     391     Element(
#     392         "<style>html, body {"
#    (...)
#     400     name="css_style",
#     401 )
#     403 figure.header.add_child(
#     404     Element(
#     405         "<style>#map {"
#    (...)
#     414     name="map_style",
#     415 )
# --> 417 super().render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\elements.py:33, in JSCSSMixin.render(self, **kwargs)
#      30 for name, url in self.default_css:
#      31     figure.header.add_child(CssLink(url), name=name)
# ---> 33 super().render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\map.py:90, in Layer.render(self, **kwargs)
#      82 if self.show:
#      83     self.add_child(
#      84         ElementAddToElement(
#      85             element_name=self.get_name(),
#    (...)
#      88         name=self.get_name() + "_add",
#      89     )
# ---> 90 super().render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\map.py:433, in Marker.render(self)
#     431 if self.icon:
#     432     self.add_child(self.SetIcon(marker=self, icon=self.icon))
# --> 433 super().render()
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\folium\map.py:527, in Popup.render(self, **kwargs)
#     521 figure = self.get_root()
#     522 assert isinstance(
#     523     figure, Figure
#     524 ), "You cannot render this Element if it is not in a Figure."
#     526 figure.script.add_child(
# --> 527     Element(self._template.render(this=self, kwargs=kwargs)),
#     528     name=self.get_name(),
#     529 )
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\branca\element.py:68, in Element.__init__(self, template, template_name)
#      65 self._template_name: Optional[str] = template_name
#      67 if template is not None:
# ---> 68     self._template = Template(template)
#      69 elif template_name is not None:
#      70     self._template = ENV.get_template(template_name)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\jinja2\environment.py:1214, in Template.__new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1167 def __new__(
#    1168     cls,
#    1169     source: t.Union[str, nodes.Template],
#    (...)
#    1187     enable_async: bool = False,
#    1188 ) -> t.Any:  # it returns a `Template`, but this breaks the sphinx build...
#    1189     env = get_spontaneous_environment(
#    1190         cls.environment_class,  # type: ignore
#    1191         block_start_string,
#    (...)
#    1212         enable_async,
#    1213     )
# -> 1214     return env.from_string(source, template_class=cls)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\jinja2\environment.py:1111, in Environment.from_string(self, source, globals, template_class)
#    1109 gs = self.make_globals(globals)
#    1110 cls = template_class or self.template_class
# -> 1111 return cls.from_code(self, self.compile(source), gs, None)
#
# File d:\Projects\SorenLKuhl.github.io\.venv\lib\site-packages\jinja2\environment.py:769, in Environment.compile(self, source, name, filename, raw, defer_init)
#     767     if filename is None:
#     768         filename = "<template>"
# --> 769     return self._compile(source, filename)
#     770 except TemplateSyntaxError:
#     771     self.handle_exception(source=source_hint)
#
# KeyboardInterrupt:

# %%
# get the average rating for each grid cell
df_avg = df.groupby('grid')['stars_x'].mean().reset_index(name='avg_stars')

# %%
# Find unique values in postal_code column
unique_postal_codes = df['postal_code'].unique()
print("Unique postal codes:", unique_postal_codes)
# Count the number of reviews for each postal code
postal_code_counts = df['postal_code'].value_counts()
print("Number of reviews for each postal code:")
print(postal_code_counts)
# Out:
# Unique postal codes: ['19103' '19130' '19107' '19102' '19146' '19152' '19104' '19147' '19114'
#  '19122' '19134' '19129' '19145' '19106' '19121' '19133' '19132' '19154'
#  '19124' '19143' '19136' '19140' '19123' '19125' '19135' '19127' '19137'
#  '19148' '19128' '19153' '19111' '19087' '19151' '19116' '19126' '19149'
#  '19150' '19144' '19141' '19139' '19115' '19120' '19131' '19118' '19119'
#  '19142']
# Number of reviews for each postal code:
# postal_code
# 19103    6055
# 19107    4211
# 19106    4019
# 19102    3869
# 19104    3495
# 19147    2920
# 19123    2900
# 19125    1764
# 19146    1585
# 19148    1374
# 19127     906
# 19145     835
# 19152     722
# 19130     715
# 19128     654
# 19114     544
# 19129     524
# 19131     497
# 19151     454
# 19153     444
# 19143     378
# 19134     265
# 19149     263
# 19118     206
# 19136     206
# 19154     195
# 19122     188
# 19135     182
# 19121     173
# 19140     147
# 19115     132
# 19124     128
# 19111     127
# 19137      95
# 19141      86
# 19116      82
# 19132      77
# 19139      65
# 19150      62
# 19144      54
# 19133      52
# 19120      37
# 19126      24
# 19087      15
# 19142      13
# 19119       7
# Name: count, dtype: int64

# %%
# Create map of postal codes to average ratings and mean longitude/latitude
postal_code_avg = df.groupby('postal_code').agg({'stars_x': 'mean', 'latitude': 'mean', 'longitude': 'mean'}).reset_index()
postal_code_avg.columns = ['postal_code', 'avg_rating', 'latitude', 'longitude']
postal_code_avg['avg_rating'] = postal_code_avg['avg_rating'].round(2)
# add a column for the number of reviews in each postal code
postal_code_avg['review_count'] = df.groupby('postal_code')['stars_x'].count().values
postal_code_avg.head()
# Out:
#   postal_code  avg_rating   latitude  longitude  review_count
# 0       19087        3.73  40.041472 -75.363647            15
# 1       19102        3.33  39.950633 -75.164726          3869
# 2       19103        3.80  39.951203 -75.170873          6055
# 3       19104        3.49  39.954443 -75.196575          3495
# 4       19106        3.84  39.949996 -75.145577          4019

# %%
# print range of review counts
print("Range of review counts:", postal_code_avg['review_count'].min(), "-", postal_code_avg['review_count'].max())
print("Average review count:", postal_code_avg['review_count'].mean())
# Out:
# Range of review counts: 7 - 6055
# Average review count: 907.5217391304348

# %%
center = [39.952583, -75.165222]  # Center of Philadelphia

# Create a folium map
m = folium.Map(location=center, zoom_start=12)
# Add postal code markers to the map
for _, row in postal_code_avg.iterrows():
	folium.Marker(
        location=[row['latitude'], row['longitude']],
        icon=DivIcon(
            icon_size=(250,36),
            icon_anchor=(0,0),
            html=f"""<div style="font-size: 12pt; color : {'red' if row['avg_rating'] < 3 else 'green'}">{row['postal_code']}<br>Avg Rating: {row['avg_rating']}<br>Review Count: {row['review_count']}</div>""",
            )
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f0bad3c74b1618f3bfbac2595f42a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f0bad3c74b1618f3bfbac2595f42a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f0bad3c74b1618f3bfbac2595f42a6 = L.map(
#                 &quot;map_29f0bad3c74b1618f3bfbac2595f42a6&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ffce3ad2d54592ea3c32dd1f169ca10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ffce3ad2d54592ea3c32dd1f169ca10.addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var marker_24cd6f49c0005e7d9d054ea67494f82a = L.marker(
#                 [40.0414717, -75.36364669999999],
#                 {
# }
#             ).addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var div_icon_907df3f35320050a1fcf02a11ad87b29 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color : green\&quot;\u003e19087\u003cbr\u003eAvg Rating: 3.73\u003cbr\u003eReview Count: 15\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_24cd6f49c0005e7d9d054ea67494f82a.setIcon(div_icon_907df3f35320050a1fcf02a11ad87b29);
#
#
#                 marker_24cd6f49c0005e7d9d054ea67494f82a.setIcon(div_icon_907df3f35320050a1fcf02a11ad87b29);
#
#
#             var marker_b6196c9323bf5aca166a344868e2c336 = L.marker(
#                 [39.95063325574689, -75.16472607017701],
#                 {
# }
#             ).addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var div_icon_ca2baaf28b68cb82923a2964ec5c8f09 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color : green\&quot;\u003e19102\u003cbr\u003eAvg Rating: 3.33\u003cbr\u003eReview Count: 3869\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_b6196c9323bf5aca166a344868e2c336.setIcon(div_icon_ca2baaf28b68cb82923a2964ec5c8f09);
#
#
#                 marker_b6196c9323bf5aca166a344868e2c336.setIcon(div_icon_ca2baaf28b68cb82923a2964ec5c8f09);
#
#
#             var marker_9655e8d9fda6c60839294d4687e9e003 = L.marker(
#                 [39.95120307124524, -75.17087265013507],
#                 {
# }
#             ).addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var div_icon_eeb07f62354323917e1c27a121f3c91b = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color : green\&quot;\u003e19103\u003cbr\u003eAvg Rating: 3.8\u003cbr\u003eReview Count: 6055\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_9655e8d9fda6c60839294d4687e9e003.setIcon(div_icon_eeb07f62354323917e1c27a121f3c91b);
#
#
#                 marker_9655e8d9fda6c60839294d4687e9e003.setIcon(div_icon_eeb07f62354323917e1c27a121f3c91b);
#
#
#             var marker_7362728e7aa5110f9f2c2444291969a5 = L.marker(
#                 [39.95444312064721, -75.19657485400101],
#                 {
# }
#             ).addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var div_icon_51de008e369ef118cfb2af27faf8acbb = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color : green\&quot;\u003e19104\u003cbr\u003eAvg Rating: 3.49\u003cbr\u003eReview Count: 3495\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_7362728e7aa5110f9f2c2444291969a5.setIcon(div_icon_51de008e369ef118cfb2af27faf8acbb);
#
#
#                 marker_7362728e7aa5110f9f2c2444291969a5.setIcon(div_icon_51de008e369ef118cfb2af27faf8acbb);
#
#
#             var marker_1d5cc274101873badce442d3bb4b24e8 = L.marker(
#                 [39.949995933858496, -75.14557679872475],
#                 {
# }
#             ).addTo(map_29f0bad3c74b1618f3bfbac2595f42a6);
#
#
#             var div_icon_64443239db7d12e750bafc843421fe40 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color : green\&quot;\u003e19106\u003cbr\u003eAvg Rating: 3.84\u003cbr\u003eReview Count: 4019\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [250, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_1d5cc274101873badce442d3bb4b24e8.setIcon(div_icon_64443239db7d12e750bafc843421fe40);
#
#
#                 marker_1d5cc274101873badce442d3bb4b24e8.setIcon(div_icon_6444
